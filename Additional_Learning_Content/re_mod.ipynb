# %%
import re

# %%
print(re.match(".*?","www.runoob,com"))
# Out:
# <re.Match object; span=(0, 0), match=''>

# %%
print(re.match("(.*) are .*?","Cats are smarter than dogs"))
# Out:
# <re.Match object; span=(0, 9), match='Cats are '>

# %%
print(re.match("(.*?)","jskahgdfiowabjaskl k  dh w"))
# Out:
# <re.Match object; span=(0, 0), match=''>

# %%
print(re.findall("(.*)","jskahgdfiowabjaskl k  dh w"))
# Out:
# ['jskahgdfiowabjaskl k  dh w', '']
