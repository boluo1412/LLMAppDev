# %%
import os
from dotenv import load_dotenv,find_dotenv
_=load_dotenv(find_dotenv())

# %%
from openai import OpenAI
client=OpenAI(
    api_key=os.environ.get("OPEN_AI_KEY"),
    base_url="https://api.deepseek.com"
)

# %%
def send_messages(prompt):
    message=[{"role":"user","content":prompt}]
    return message

# %%
def get_completion(prompt,model="deepseek-v4-flash",temperature=0):
    response=client.chat.completions.create(model=model,messages=send_messages(prompt),temperature=temperature)
    if len(response.choices) > 0:
        return response.choices[0].message.content
    return "生成答案时出错"

# %%
get_completion("你好，介绍一下你自己吧")
# Out:
# '你好呀！我是 **DeepSeek**，由深度求索公司创造的 AI 助手。简单介绍一下：\n\n- 我可以陪你聊天、答疑、写作、翻译、编程、总结、头脑风暴等。\n- 支持上传图片、PDF、Word、Excel、PPT、TXT 等文件，读取其中文字，也能分析图片中的可见信息。\n- 支持联网搜索，不过需要你手动开启。\n- 上下文很长，可以一次性处理大量内容；知识截止到 **2026年2月**。\n- 目前免费使用，App 端支持语音输入，可在官方应用商店下载。\n\n你可以直接告诉我想做什么，我会尽力帮你。😊'

# %%
prompt = f"""
请生成包括书名、作者和类别的三本虚构的、非真实存在的中文书籍清单，\
并以 JSON 格式提供，其中包含以下键:book_id、title、author、genre。
"""
response = get_completion(prompt)
print(response)
# Out:
# [
#   {
#     "book_id": "F001",
#     "title": "月蚀图书馆的守夜人",
#     "author": "陆栖迟",
#     "genre": "魔幻现实主义"
#   },
#   {
#     "book_id": "F002",
#     "title": "第七码头的时间修补术",
#     "author": "苏砚舟",
#     "genre": "科幻"
#   },
#   {
#     "book_id": "F003",
#     "title": "盐风镇手札",
#     "author": "江蘅",
#     "genre": "乡土文学"
#   }
# ]

# %%
#由于deepseek官方没有提供embedding模型，该段代码仅供参考
 
# def openai_embedding(text:str,model:str=None):
#     client=OpenAI(
#     api_key=os.environ.get("OPEN_AI_KEY"),
#     base_url="https://api.deepseek.com"
#     )
#     if model==None:
#         model="deepseek-embedding"
    
#     response=client.embeddings.create(input=text,model=model)
#     return response

# response=openai_embedding(text="今天是一个天气晴朗的日子")
# print(response.data[0].embedding)
